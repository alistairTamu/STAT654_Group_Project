# %%
import pandas as pd

pd.set_option('display.max_columns', None)
data = pd.read_csv('globalterrorismdb_0221dist.csv', skiprows=[1], skipinitialspace=True)
data.head(5)
data['violence_level'] = (
    1.5 * data['nkill'].fillna(0) + data['nwound'].fillna(0)
).where(
    data['nkill'].notna() | data['nwound'].notna()
)
#135 columns, 201,182 rows
# Out:
# C:\Users\alist\AppData\Local\Temp\ipykernel_36780\3743737090.py:5: DtypeWarning: Columns (4,31,33,54,61,62,63,76,79,90,92,94,96,114,115,121) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv('globalterrorismdb_0221dist.csv', skiprows=[1], skipinitialspace=True)

# %%
pd.set_option('display.max_columns', None)
print(data.columns.tolist())
# Out:
# ['eventid', 'iyear', 'imonth', 'iday', 'approxdate', 'extended', 'resolution', 'country', 'country_txt', 'region', 'region_txt', 'provstate', 'city', 'latitude', 'longitude', 'specificity', 'vicinity', 'location', 'summary', 'crit1', 'crit2', 'crit3', 'doubtterr', 'alternative', 'alternative_txt', 'multiple', 'success', 'suicide', 'attacktype1', 'attacktype1_txt', 'attacktype2', 'attacktype2_txt', 'attacktype3', 'attacktype3_txt', 'targtype1', 'targtype1_txt', 'targsubtype1', 'targsubtype1_txt', 'corp1', 'target1', 'natlty1', 'natlty1_txt', 'targtype2', 'targtype2_txt', 'targsubtype2', 'targsubtype2_txt', 'corp2', 'target2', 'natlty2', 'natlty2_txt', 'targtype3', 'targtype3_txt', 'targsubtype3', 'targsubtype3_txt', 'corp3', 'target3', 'natlty3', 'natlty3_txt', 'gname', 'gsubname', 'gname2', 'gsubname2', 'gname3', 'gsubname3', 'motive', 'guncertain1', 'guncertain2', 'guncertain3', 'individual', 'nperps', 'nperpcap', 'claimed', 'claimmode', 'claimmode_txt', 'claim2', 'claimmode2', 'cla
# ...

# %%
print(data['gname'].unique())
print(len(data['gname'].unique()))
# Out:
# ['23rd of September Communist League' 'Unknown' 'Black Nationalists' ...
#  'Mayhem Squads' 'Mai Mai Kyandenga Militia'
#  'Popular Nationalist Insurgency Command of the Large Brazilian Integralist Family']
# 3670

# %%
print(data['violence_level'].unique())
print(len(data['violence_level'].unique()))
# Out:
# [0.00000e+00 1.50000e+00         nan 1.00000e+00 2.00000e+00 7.00000e+00
#  1.95000e+01 7.05000e+01 3.00000e+00 1.70000e+01 5.00000e+00 5.40000e+01
#  2.50000e+00 1.00000e+01 1.20000e+01 1.35000e+01 2.00000e+01 7.50000e+00
#  4.50000e+00 5.50000e+00 8.00000e+00 8.50000e+00 2.60000e+01 3.50000e+00
#  1.30000e+01 1.25000e+01 2.70000e+01 3.75000e+01 2.25000e+01 6.00000e+00
#  3.90000e+01 1.45000e+01 2.75000e+01 2.95000e+01 1.05000e+01 1.33000e+02
#  5.60000e+01 1.10000e+01 2.40000e+01 1.11000e+02 1.21500e+02 9.00000e+00
#  4.00000e+00 3.20000e+01 2.39500e+02 6.25000e+01 1.50000e+01 2.10000e+01
#  2.45000e+01 9.50000e+01 4.65000e+01 3.40000e+01 3.15000e+01 1.07500e+02
#  1.14000e+02 4.25000e+01 6.60000e+01 4.05000e+01 1.32000e+02 8.80000e+01
#  3.70000e+01 3.25000e+01 2.05000e+01 1.55000e+01 9.75000e+01 9.60000e+01
#  5.70000e+01 1.40000e+01 5.90000e+01 1.40500e+02 3.30000e+01 1.75000e+01
#  1.80000e+01 1.65000e+01 4.30000e+01 1.85000e+01 2.85000e+01 7.10000e+01
# ...

# %%
print(data['attacktype1_txt'].unique())
print(len(data['attacktype1_txt'].unique()))
# Out:
# ['Hostage Taking (Kidnapping)' 'Assassination' 'Bombing/Explosion'
#  'Facility/Infrastructure Attack' 'Armed Assault' 'Hijacking' 'Unknown'
#  'Unarmed Assault' 'Hostage Taking (Barricade Incident)']
# 9

# %%
print(data['propvalue'].unique())
print(len(data['propvalue'].unique()))
print(data['propvalue'].isna().sum())
# Out:
# [            nan  2.25000000e+04  6.00000000e+04  0.00000000e+00
#   3.05000000e+02  2.00000000e+06  1.70000000e+04  2.50000000e+03
#   2.20000000e+03  5.00000000e+03  8.80000000e+03  3.00000000e+03
#   4.18900000e+03  2.00000000e+05  1.00000000e+03  1.00000000e+06
#   8.00000000e+03  3.50000000e+05  4.50000000e+02  1.00000000e+05
#   3.00000000e+06  2.00000000e+03  5.00000000e+02  2.00000000e+02
#   3.20000000e+05  2.50000000e+04  4.00000000e+03  1.05000000e+05
#   7.00000000e+05  1.50000000e+04  5.00000000e+04  3.00000000e+04
#   2.50000000e+05  7.50000000e+04  2.00000000e+04  4.00000000e+04
#   3.33000000e+02  1.00000000e+04  9.00000000e+03  1.60000000e+03
#   6.00000000e+05  2.50000000e+06  2.31000000e+05  1.50000000e+05
#   3.00000000e+05  7.00000000e+03  1.50000000e+03  2.35000000e+04
#   6.00000000e+02  5.00000000e+05  2.75000000e+03  1.50000000e+06
#   1.60000000e+05  5.00000000e+06  6.00000000e+03  4.00000000e+02
# ...

# %%
print(data['propvalue'].unique())
print(len(data['propvalue'].unique()))
print(data['propvalue'].isna().sum())

# %%
print(data['iyear'].unique())
print(len(data['iyear'].unique()))
# Out:
# [1970 1971 1972 1973 1974 1975 1976 1977 1978 1979 1980 1981 1986 1982
#  1983 1984 1985 1987 1988 1989 1990 1991 1992 1994 1995 1996 1997 1998
#  1999 2000 2001 2002 2003 2004 2005 2006 2007 2008 2009 2010 2011 2012
#  2013 2014 2015 2016 2017 2018 2019]
# 49

# %% [markdown]
# Potential ideas for project:
#
# Study of areas where different types of attacks occur.
# Either in terms of attack type, or target type.
#
# We have longitude/latitude, may be interesting to see if north vs south hemishpere changes things.
#
# Attack types preffered by various groups?
#
# Can do a study on escalation (or de-escalation) of attacks (split into several different categories) across the range of dates we have (1970-2019)
#
# study of violence level by various groups (Im not entirely sure from the names of the columns, but I think there are data points on number of wounded and number of kills)
#
# (We probably want some combination of a few of these options as it has to be a decent length report)
#
# I imagine the first section of the project/report will be focused on visualizing the data with various graphs and creating a simple but thorough summary of the data used (We may use a subset depending on if the data is too large)
#
# And then we'll move from there to a specific question or two that will require us to build a model. (e.g. what factors lead to the deadliest terror attacks). This will allow us to use regression properly to build a model and see which variables have more significant effects.
#
#
# First Steps:
#
# We will need to get rid of some of the columns that are redundant. (e.g. targtype1 and targtype1_txt) The former is an index number representing a type of target, the latter is the actual target type.
#
# Clearing out null data will be the next step. Certain columns are very near completely null. (e.g. attacktype3_txt) This column has 200,612 null values out of a total of 201,182 rows.
# This part will have to depend on exactly what some of these rows mean, as well as if we want to make the missing values part of the study (e.g.' How many attacks were executed with three different styles of attack')

# %% [markdown]
# We have a historical dataset on global terrorism. Our plan is to clean the data, narrow down the categories that we'd actually like to use. Then do some data visualization on a few categories. And finally end with fitting a model for predicting the severity of an attack (e.g. Deaths, injuries, or property damage) based on factors such as Attack types, targets, and location. (We may change which of these variables we end up using, these were just examples)
